# %%
from compare_rewards import EvaluateMaze

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
maze_configs = [((10, 10), 1, 1, 0.2)]
discount_factors = [0.9]
noises = [0.0, 0.01, 0.1, .2, 0.3, 0.4]

evaluator = EvaluateMaze(maze_configs, discount_factors, noises, vwait=50)
evaluator.evaluate(iter_=1, visualize=False, plot=True)
# Out:
# ** Experiment Started **
# - Total Iterations: 1
# ------------------------------------------------------------------------------------------
# << Performed Policy Iteration >>
# Current Settings: Maze(size=(10, 10), n_goals=1, n_fires=1, p=0.2), γ=0.90,, noise=0.0000
# ------------------------------------------------------------------------------------------
# Point: [1], Avg Reward: 0.81, Expected Reward: 0.81000, Diff: 0.00000
# Point: [2], Avg Reward: 0.20589, Expected Reward: 0.20589, Diff: 0.00000
# Point: [3], Avg Reward: 0.729, Expected Reward: 0.72900, Diff: 0.00000
# Point: [4], Avg Reward: 0.0, Expected Reward: 0.00000, Diff: 0.00000
# Point: [5], Avg Reward: 0.53144, Expected Reward: 0.53144, Diff: 0.00000
# ------------------------------------------------------------------------------------------
# << Performed Policy Iteration >>
# Current Settings: Maze(size=(10, 10), n_goals=1, n_fires=1, p=0.2), γ=0.90,, noise=0.0100
# ...

# %%
maze_configs = [((10, 10), 1, 1, 0.2)]
discount_factors = [0.9]
noises = [0.2]

evaluator = EvaluateMaze(maze_configs, discount_factors, noises, vwait=250)
evaluator.evaluate(iter_=1, visualize=True, plot=False)
# Out:
# ** Experiment Started **
# - Total Iterations: 1
# ------------------------------------------------------------------------------------------
# << Performed Policy Iteration >>
# Current Settings: Maze(size=(10, 10), n_goals=1, n_fires=1, p=0.2), γ=0.90,, noise=0.2000
# ------------------------------------------------------------------------------------------
# Point: [1], Avg Reward: 0.729, Expected Reward: 0.56739, Diff: 0.16161
# Point: [2], Avg Reward: 1.0, Expected Reward: 0.86924, Diff: 0.13076
# Point: [3], Avg Reward: 0.43047, Expected Reward: 0.25277, Diff: 0.17770
# Point: [4], Avg Reward: 0.1853, Expected Reward: 0.17389, Diff: 0.01141
# Point: [5], Avg Reward: 0.81, Expected Reward: 0.63062, Diff: 0.17938
# ------------------------------------------------------------------------------------------
